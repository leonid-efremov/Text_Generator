# %% [markdown]
# Генератор теста
# main файл:
#     - простая грамматическая модель
#     - интерфейс для вызова LSTM модели
#     - основная программа

# %%
from Text_Generator import TextGenerator

# %%
model = TextGenerator(model_type='LSTM')

layers_sizes =  {'hidden_size': 128,     # for LSTM model
                 'embedding_size': 128}

# %%
train_texts = 'books.csv'

model.prepare(file_path=train_texts, layers_sizes=layers_sizes, pretrained=True)

# %%
#start_word = str(input('Enter your word:'))  # generate phrase from word
#gen.init_word = 'утро доброе'  # start_word

# %%
train_parameters = {'batch_size': 64,
                    'seq_len': 256,
                    'n_epochs': 5000,
                    'lr': 1e-3}
phrase = model.generate(train_parameters=train_parameters)
# Out:
#  и про намисле оруйне говорил что так извились истрои на только не мог с деня до чегото в нет извоюнно вобирали что и во сне вернулась спал было воядя тато городе необедить из кухню сказал огридку за то что станул и странные и считатьколврего все тотели взмолный спетаака и прочитай полагаюта думають но на стекло пальцем большим тяжку первом должек и попробовал на голову и примернулся огриду отскачало профессор макгонаголл неодобрительно до карамелек ли комчакойки гарри не понимаешь когда его заск
